# %% [markdown]
# ### range()

# %% [markdown]
# As an experienced Python developer, or even a beginner, you've likely heard of the Python range() function. But what does it do? In a nutshell, it generates a list of numbers, which is generally used to iterate over with for loops. There's many use cases. Often you will want to use this when you want to perform an action X number of times, where you may or may not care about the index. Other times you may want to iterate over a list (or another iterable object), while being able to have the index available.

# %% [markdown]
# ## For

# %%
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# Muito importante: repare que o último número, $i = 5$, não é exibido. Esquecer isso pode afetar a elaboração de seus loops em programas que você venha a criar.

# %%
print ("\n", "Primeiro caso:")

for i in range(5):
     print(i)

print ("\n", "Segundo caso: dois parâmetros, um de início e outro de final (3 a 6)")
# Two parameters
for i in range(3, 6):
     print(i)
        
print ("\n", "Terceiro caso: com passo de 2 (de 4 a 10)")
# Three parameters
for i in range(4, 10, 2):
     print(i)

print ("\n", "Quarto caso: indo de trás para frente (de 0 a -3)")
# Going backwards
for i in range(0, -3):
     print(i)
        
print ("\n", "Quarto caso: indo de trás para frente com passo -2 (de 0 a -10)")
# Going backwards
for i in range(0, -10, -2):
     print(i)
# Out:
#  Primeiro caso:
# 0
# 1
# 2
# 3
# 4
#
#  Segundo caso: dois parâmetros, um de início e outro de final (3 a 6)
# 3
# 4
# 5
#
#  Terceiro caso: com passo de 2 (de 4 a 10)
# 4
# 6
# 8
#
#  Quarto caso: indo de trás para frente (de 0 a -3)
#
#  Quarto caso: indo de trás para frente com passo -2 (de 0 a -10)
# 0
# -2
# -4
# -6
# -8

# %% [markdown]
# All parameters must be integers.
# All parameters can be positive or negative.
# range() (and Python in general) is 0-index based, meaning list indexes start at 0, not 1. eg. The syntax to access the first element of a list is mylist[0]. Therefore the last integer generated by range() is up to, but not including, stop. For example range(0, 5) generates integers from 0 up to, but not including, 5.

# %% [markdown]
# ## While

# %%
i = 1

while i <= 5:
    print('i vale: {}'.format(i))
    i = i + 1
# Out:
# i vale: 1
# i vale: 2
# i vale: 3
# i vale: 4
# i vale: 5

# %% [markdown]
# ## List comprehension

# %%
out = []

x = [1,2,3,4]

for item in x:
    out.append(item)
    
print(out)
# Out:
# [1, 2, 3, 4]

# %%
out = []

x = [1,2,3,4]

# list comprehension
out = [item**2 for item in x]
    
print(out)
# Out:
# [1, 4, 9, 16]
